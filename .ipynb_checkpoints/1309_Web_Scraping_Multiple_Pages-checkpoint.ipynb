# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
pd.set_option('display.max_rows', None)
import collections
import difflib
import random

# %%
def load_clean_edit_df():
    """
    Load dataframe from csv.
    Make columns lowercase.
    Add columns with simplified song names.
    Return reordered dataframe.
    """

    df = pd.read_csv("Billboard_Top_100.csv")
    df.columns = [col.lower() for col in df.columns]

    df["song_lower"] = [song.lower() for song in df["song"]]
    df["song_lower_shorthand"] = [song.split("(")[0].lower().replace("'", "").replace(".", "").replace(",", "").strip() 
                                  for song in df["song"]]

    df = df[["song", "song_lower", "song_lower_shorthand", "artist"]]
    
    return df

df = load_clean_edit_df()

# %%
df
# Out:
#                                       song  \
# 0                                As It Was
# 1                                Bad Habit
# 2                          About Damn Time
# 3   Running Up That Hill (A Deal With God)
# 4                                  Sunroof
# 5                           Hold Me Closer
# 6                        Super Freaky Girl
# 7              I Like You (A Happier Song)
# 8                            Break My Soul
# 9                               Wait For U
# 10                         Me Porto Bonito
# 11                      Late Night Talking
# 12                               You Proof
# 13                         I Ain't Worried
# 14                The Kind Of Love We Make
# 15                        Titi Me Pregunto
# 16                                 God Did
# 17                             First Class
# 18                              Heat Waves
# 19                           Wasted On You
# 20                           Staying Alive
# 21            She Had Me At Heads Carolina
# 22                             Jimmy Cooks
# 23                                    Stay
# 24                                   Vegas
# 25                           Glimpse Of Us
# 26                       Last Night Lonely
# 27                                5 Foot 9
# 28                               Beautiful
# 29                             Moscow Mule
# 30                                Big Time
# 31                              Big Energy
# 32                       Betty (Get Money)
# 33                                   Ghost
# 34                                 Shivers
# 35                           Beat The Odds
# 36                                Gatubela
# 37                   Rock And A Hard Place
# 38                                  Efecto
# 39                             In A Minute
# 40                 Cold Heart (PNAU Remix)
# 41                 Something In The Orange
# 42                         Son Of A Sinner
# 43                                    Numb
# 44                            Fall In Love
# 45                                Provenza
# 46                          Left And Right
# 47                         Numb Little Bug
# 48                 Use This Gospel (Remix)
# 49                             Unstoppable
# 50                        Wishful Drinking
# 51               Like I Love Country Music
# 52                              Pink Venom
# 53                          Dah Dah DahDah
# 54                          Juice WRLD Did
# 55                                  Sticky
# 56                              Keep Going
# 57                                   Bones
# 58                       Victoria’s Secret
# 59                                Hot Shit
# 60                               Free Mind
# 61                             Sleazy Flow
# 62                                 So Good
# 63                   With A Woman You Love
# 64                                   Party
# 65                                   Party
# 66                               Last Last
# 67                           Ojitos Lindos
# 68                             Die For You
# 69                         Truth About You
# 70                             Golden Hour
# 71                           Where It Ends
# 72                       F.N.F. (Let's Go)
# 73                     Despues de La Playa
# 74                                Despecha
# 75                                   Alone
# 76                           It Ain't Safe
# 77                               No Secret
# 78                                Neverita
# 79                              Pick Me Up
# 80                         I'm Good (Blue)
# 81                          Whiskey On You
# 82                                   Tarot
# 83                            She Likes It
# 84                             Ghost Story
# 85                              Let's Pray
# 86                       Until I Found You
# 87                                All Mine
# 88                           Bad Decisions
# 89                         Alien Superstar
# 90                       Puffin On Zootiez
# 91                              Half Of Me
# 92              What My World Spins Around
# 93              Hotel Lobby (Unc And Phew)
# 94                              La Bachata
# 95                 Thought You Should Know
# 96                 2 Be Loved (Am I Ready)
# 97                       Wait In The Truck
# 98                            La Corriente
# 99            Bzrp Music Sessions, Vol. 52
#
#                                 song_lower          song_lower_shorthand  \
# 0                                as it was                     as it was
# 1                                bad habit                     bad habit
# 2                          about damn time               about damn time
# 3   running up that hill (a deal with god)          running up that hill
# 4                                  sunroof                       sunroof
# 5                           hold me closer                hold me closer
# 6                        super freaky girl             super freaky girl
# 7              i like you (a happier song)                    i like you
# 8                            break my soul                 break my soul
# 9                               wait for u                    wait for u
# 10                         me porto bonito               me porto bonito
# 11                      late night talking            late night talking
# 12                               you proof                     you proof
# 13                         i ain't worried                i aint worried
# 14                the kind of love we make      the kind of love we make
# 15                        titi me pregunto              titi me pregunto
# 16                                 god did                       god did
# 17                             first class                   first class
# 18                              heat waves                    heat waves
# 19                           wasted on you                 wasted on you
# 20                           staying alive                 staying alive
# 21            she had me at heads carolina  she had me at heads carolina
# 22                             jimmy cooks                   jimmy cooks
# 23                                    stay                          stay
# 24                                   vegas                         vegas
# 25                           glimpse of us                 glimpse of us
# 26                       last night lonely             last night lonely
# 27                                5 foot 9                      5 foot 9
# 28                               beautiful                     beautiful
# 29                             moscow mule                   moscow mule
# 30                                big time                      big time
# 31                              big energy                    big energy
# 32                       betty (get money)                         betty
# 33                                   ghost                         ghost
# 34                                 shivers                       shivers
# 35                           beat the odds                 beat the odds
# 36                                gatubela                      gatubela
# 37                   rock and a hard place         rock and a hard place
# 38                                  efecto                        efecto
# 39                             in a minute                   in a minute
# 40                 cold heart (pnau remix)                    cold heart
# 41                 something in the orange       something in the orange
# 42                         son of a sinner               son of a sinner
# 43                                    numb                          numb
# 44                            fall in love                  fall in love
# 45                                provenza                      provenza
# 46                          left and right                left and right
# 47                         numb little bug               numb little bug
# 48                 use this gospel (remix)               use this gospel
# 49                             unstoppable                   unstoppable
# 50                        wishful drinking              wishful drinking
# 51               like i love country music     like i love country music
# 52                              pink venom                    pink venom
# 53                          dah dah dahdah                dah dah dahdah
# 54                          juice wrld did                juice wrld did
# 55                                  sticky                        sticky
# 56                              keep going                    keep going
# 57                                   bones                         bones
# 58                       victoria’s secret             victoria’s secret
# 59                                hot shit                      hot shit
# 60                               free mind                     free mind
# 61                             sleazy flow                   sleazy flow
# 62                                 so good                       so good
# 63                   with a woman you love         with a woman you love
# 64                                   party                         party
# 65                                   party                         party
# 66                               last last                     last last
# 67                           ojitos lindos                 ojitos lindos
# 68                             die for you                   die for you
# 69                         truth about you               truth about you
# 70                             golden hour                   golden hour
# 71                           where it ends                 where it ends
# 72                       f.n.f. (let's go)                           fnf
# 73                     despues de la playa           despues de la playa
# 74                                despecha                      despecha
# 75                                   alone                         alone
# 76                           it ain't safe                  it aint safe
# 77                               no secret                     no secret
# 78                                neverita                      neverita
# 79                              pick me up                    pick me up
# 80                         i'm good (blue)                       im good
# 81                          whiskey on you                whiskey on you
# 82                                   tarot                         tarot
# 83                            she likes it                  she likes it
# 84                             ghost story                   ghost story
# 85                              let's pray                     lets pray
# 86                       until i found you             until i found you
# 87                                all mine                      all mine
# 88                           bad decisions                 bad decisions
# 89                         alien superstar               alien superstar
# 90                       puffin on zootiez             puffin on zootiez
# 91                              half of me                    half of me
# 92              what my world spins around    what my world spins around
# 93              hotel lobby (unc and phew)                   hotel lobby
# 94                              la bachata                    la bachata
# 95                 thought you should know       thought you should know
# 96                 2 be loved (am i ready)                    2 be loved
# 93                                    Quavo & Takeoff
# 94                                      Manuel Turizo
# 95                                      Morgan Wallen
# 96                                              Lizzo
# 97                      HARDY Featuring Lainey Wilson
# 98                              Bad Bunny & Tony Dize
# 99                                 Bizarrap & Quevedo

# %%
def get_songs(df):

    song_list = list(df["song"])
    song_list_lower = list(df["song_lower"])
    song_list_lower_shorthand = list(df["song_lower_shorthand"])
    duplicate_songs = [item for item, count in collections.Counter(song_list_lower).items() if count > 1]
    
    return song_list, song_list_lower, song_list_lower_shorthand, duplicate_songs

song_list, song_list_lower, song_list_lower_shorthand, duplicate_songs = get_songs(df)

def get_and_check_user_input():
    """
    Get user's input and check whether the song is in Top 100.
    Ask for input until valid top 100 song is given.
    """
    user_input = input("Pick a hot song: ")
    ui_easified = user_input.split("(")[0].lower().replace("'", "").replace(".", "").replace(",", "").strip()
    #ui_easified = user_input.lower().replace("'", "").replace(".", "").replace(",", "").replace("(","").replace(")","").strip() 
    
    if ui_easified in list(df["song_lower_shorthand"]):
        ui_idx = list(df["song_lower_shorthand"]).index(ui_easified)

        return df["song"][ui_idx]

    else:
        diff_match = difflib.get_close_matches("bad rabit", list(df["song"]))[0]
        yn_input = input(f"I assume you meant {diff_match} [Y] / [N]")
        if yn_input.lower() == "y":
            return diff_match
        else:
            user_input = get_and_check_user_input()
        
        #for idx, song in enumerate(song_list_lower_shorthand):
#            
            #matcher = difflib.SequenceMatcher(None, ui_easified, song)
            #match = max(size for _,_,size in matcher.get_matching_blocks()) >= \
                    #int(np.floor(0.5*len(song)))

            #if match:
                #congruent_song = song_list[idx]
                #print(f"I assume you mean {congruent_song}!?")
                #return congruent_song

            #else:
                #print("------------")
                #print("Your chosen song is NOT in the Top 100!")
                #print("Choose another song: ")

                #user_input = get_and_check_user_input()

                #return user_input

    
def check_if_song_duplicate(user_input):
    """
    Check if chosen song exists more than once.
    Prompt user to choose if song is duplicate.
    """
    artists = list(df[df["song_lower_shorthand"].str.contains(user_input, case=False)]["artist"].values)
    
    if len(artists) > 1:
        
        print(f"There is more than one song named '{user_input}'")
        print("------------")
        print(f"Which of the {len(artists)} artists did you mean?")
        
        input_duplicate = input(f"Select {len(artists)-1} for {artists[0]} or \n \
        {len(artists)} for {artists[1]}")
        
        if input_duplicate not in [str(i) for i in range(1,len(artists)+1)]:
            print("------------")
            print("Invalid input - please choose again!")
            input_duplicate = input(f"Select {len(artists)-1} for {artists[0]} or \n \
            {len(artists)} for {artists[1]}")
        
        artists = artists[int(input_duplicate)-1]
        
        #print("------------")
        
        print(f"You chose '{user_input}' by {artists}")
        return artists
    return artists

# %%
def result():
    
    user_input = get_and_check_user_input()
    #print(user_input)
    
    artist = check_if_song_duplicate(user_input)
    #print(artist)
   
    if len(artist) == 1:
        print(f"You chose '{user_input}' by {artist}")
        
    recom_new_song = random.choice(song_list)
    recom_new_song_artist = list(df[df["song"].str.contains(recom_new_song, case=False)]["artist"].values)
    
    print("------------")    
    print(f"You might also like '{recom_new_song}' by {recom_new_song_artist}.")

result()
# Out:
# Pick a hot song: as it war
# I assume you meant Bad Habit [Y] / [N]y
# You chose 'Bad Habit' by ['Steve Lacy']
# ------------
# You might also like 'Titi Me Pregunto' by ['Bad Bunny'].
