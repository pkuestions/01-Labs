# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
pd.set_option('display.max_rows', None)
import collections
import difflib
import random

# %%
url = "https://playback.fm/charts/rock/2010"
response = requests.get(url)
print(response.status_code) # 200 status code means OK!
soup = BeautifulSoup(response.content, "html.parser")

url_list = ["https://playback.fm/charts/rock/" + str(y) for y in range(2010, 2022, 1)]
# Out:
# 200

# %%
song_list = []
artist_list = []

for url in url_list:
    print(f"Working on {url}...")
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    song_list.extend([soup.select("a span.song")[song].get_text() 
                      for song in range(len(soup.select("a span.song")))])
    artist_list.extend([soup.select("tr td a.artist")[artist].get_text().strip() 
                        for artist in range(len(soup.select("tr td a.artist")))])
    
df_rock_top_100s = pd.DataFrame(data={
    "song": song_list,
    "artist": artist_list
})
# Out:
# Working on https://playback.fm/charts/rock/2010...
# Working on https://playback.fm/charts/rock/2011...
# Working on https://playback.fm/charts/rock/2012...
# Working on https://playback.fm/charts/rock/2013...
# Working on https://playback.fm/charts/rock/2014...
# Working on https://playback.fm/charts/rock/2015...
# Working on https://playback.fm/charts/rock/2016...
# Working on https://playback.fm/charts/rock/2017...
# Working on https://playback.fm/charts/rock/2018...
# Working on https://playback.fm/charts/rock/2019...
# Working on https://playback.fm/charts/rock/2020...
# Working on https://playback.fm/charts/rock/2021...

# %%
def load_clean_edit_df(df):
    """
    Load dataframe from csv.
    Make columns lowercase.
    Add columns with simplified song names.
    Return reordered dataframe.
    """

    df.columns = [col.lower() for col in df.columns]

    df["song_lower"] = [song.lower() for song in df["song"]]
    df["song_lower_shorthand"] = [song.split("(")[0].lower().replace("'", "").replace(".", "").replace(",", "").strip() 
                                  for song in df["song"]]

    df = df[["song", "song_lower", "song_lower_shorthand", "artist"]]
    
    return df

df = load_clean_edit_df(df_rock_top_100s)

# %%
def get_songs(df):

    song_list = list(df["song"])
    song_list_lower = list(df["song_lower"])
    song_list_lower_shorthand = list(df["song_lower_shorthand"])
    duplicate_songs = [item for item, count in collections.Counter(song_list_lower).items() if count > 1]
    
    return song_list, song_list_lower, duplicate_songs

song_list, song_list_lower, duplicate_songs = get_songs(df)

def get_and_check_user_input():
    """
    Get user's input and check whether the song is in Top 100.
    Ask for input until valid top 100 song is given.
    """
    user_input = input("Pick a hot song: ")
    ui_easified = user_input.split("(")[0].lower().replace("'", "").replace(".", "").replace(",", "").strip() 
    
    if ui_easified in list(df["song_lower_shorthand"]):
        ui_idx = list(df["song_lower_shorthand"]).index(ui_easified)

        print('You chose:')
        return df["song"][ui_idx]

    else:
        print("------------")
        print("Your chosen song is NOT in the Top 100!")
        print("Choose another song: ")

        user_input = get_and_check_user_input()
        
        return user_input

#def get_and_check_user_input():
#    
    #user_input = input("Pick a hot song: ")
#    
    #if "'" in user_input:
        #if user_input.lower() in song_list_lower:

            #return user_input

        #else:
            #print("------------")
            #print("Your chosen song is NOT in the Top 100!")
            #print("Choose another song: ")

            #user_input = get_and_check_user_input()
            ##get_and_check_user_input()

            #return user_input
#        
    #else:
        #if user_input.lower() in song_list_lower_shorthand:

            #return user_input

        #else:
            #print("------------")
            #print("Your chosen song is NOT in the Top 100!")
            #print("Choose another song: ")

            #user_input = get_and_check_user_input()

            #return user_input
    
#def get_and_check_user_input():
#    
    #user_input = input("Pick a hot song: ")
#    
    #if user_input.lower() in song_list_lower:
        #return user_input
#    
    #else:
        #user_input = user_input.lower().replace(" ", "")

        #for idx, song in enumerate(song_list_lower):

            #song = song.lower().replace(" ", "")
            #matcher = difflib.SequenceMatcher(None, user_input, song)

            #match = max(size for _,_,size in matcher.get_matching_blocks()) >= \
                    #int(np.floor(0.7*len(song)))

            #if match:
                #congruent_song = song_list[idx]
                #print(f"I assume you mean {congruent_song}!?")
                #return congruent_song
#            
            ##else:
                ##print("Your chosen song is NOT in the Top 100!")
                ##print("Choose another song: ")
##                
                ##get_and_check_user_input()
    
def check_if_song_duplicate(user_input):
    """
    Check if chosen song exists more than once.
    Prompt user to choose if song is duplicate.
    """
    artists = list(df[df["song"].str.contains(user_input, case=False)]["artist"].values)
    
    if len(artists) > 1:
        print(f"There is more than one song named '{user_input}'")
        
        print("------------")
        
        print(f"Which of the {len(artists)} artists did you mean?")
        
        input_duplicate = input(f"Select {len(artists)-1} for {artists[0]} or \n \
        {len(artists)} for {artists[1]}")
        if input_duplicate not in [str(i) for i in range(1,len(artists)+1)]:
            print("------------")
            print("Invalid input - please choose again!")
            input_duplicate = input(f"Select {len(artists)-1} for {artists[0]} or \n \
            {len(artists)} for {artists[1]}")
        
        chosen_duplicate_artist = artists[int(input_duplicate)-1]
        
        print("------------")
        
        print(f"You chose '{user_input}' by {chosen_duplicate_artist}")
        return True, chosen_duplicate_artist
    else:
        return False, artists

# %%
def result():
    
    user_input = get_and_check_user_input()
    #print(user_input)
    
    artist = check_if_song_duplicate(user_input)
    #print(artist)
   
    if len(artist) == 1:
        print(f"You chose '{user_input}' by {artist}")
        
    recom_new_song = random.choice(song_list)
    recom_new_song_artist = list(df[df["song"].str.contains(recom_new_song, case=False)]["artist"].values)
    
    print("------------")    
    print(f"You might also like '{recom_new_song}' by {recom_new_song_artist}.")

result()
# Out:
# Pick a hot song: rad habit
# I assume you meant [] [Y] / [N]y
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 18>()
#      15     print("------------")
#      16     print(f"You might also like '{recom_new_song}' by {recom_new_song_artist}.")
# ---> 18 result()
#
# Input In [12], in result()
#       3 user_input = get_and_check_user_input()
#       4 #print(user_input)
# ----> 6 artist = check_if_song_duplicate(user_input)
#       7 #print(artist)
#       9 if len(artist) == 1:
#
# Input In [11], in check_if_song_duplicate(user_input)
#      34 def check_if_song_duplicate(user_input):
#      35     """
#      36     Check if chosen song exists more than once.
#      37     Prompt user to choose if song is duplicate.
#      38     """
# ---> 39     artists = list(df[df["song_lower_shorthand"].str.contains(user_input, case=False)]["artist"].values)
#      41     if len(artists) > 1:
#      43         print(f"There is more than one song named '{user_input}'")
#
# File ~\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:1214, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1089 @forbid_nonstring_types(["bytes"])
#    1090 def contains(self, pat, case=True, flags=0, na=None, regex=True):
#    1091     r"""
#    1092     Test if pattern or regex is contained within a string of a Series or Index.
#    1093
#    (...)
#    1212     dtype: bool
#    1213     """
# -> 1214     if regex and re.compile(pat).groups:
#    1215         warnings.warn(
#    1216             "This pattern is interpreted as a regular expression, and has "
#    1217             "match groups. To actually get the groups, use str.extract.",
#    1218             UserWarning,
#    1219             stacklevel=find_stack_level(),
#    1220         )
#    1222     result = self._data.array._str_contains(pat, case, flags, na, regex)
#
# File ~\Anaconda3\lib\re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File ~\Anaconda3\lib\re.py:294, in _compile(pattern, flags)
#     292     flags = flags.value
#     293 try:
# --> 294     return _cache[type(pattern), pattern, flags]
#     295 except KeyError:
#     296     pass
#
# TypeError: unhashable type: 'list'

# %%
get_and_check_user_input()
# Out:
# Pick a hot song: as it war
# I assume you meant [] [Y] / [N]n
# Pick a hot song: bad habit
# I assume you meant [] [Y] / [N]y

# %%
df
# Out:
#                                                    song  \
# 0                                       The Sex Is Good
# 1                                    Another Way to Die
# 2                                            Resistance
# 3                                   Waiting for the End
# 4                                           Lay Me Down
# 5                                      Kings And Queens
# 6                                            Tighten Up
# 7                                     Porn Star Dancing
# 8                                                  1901
# 9                                          The Catalyst
# 10                                  Say You'll Haunt Me
# 11                                Back Against The Wall
# 12                                          Radioactive
# 13                                 Cryin' Like A Bi**h!
# 14                                        Your Decision
# 15                                     If You Only Knew
# 16                                                Snuff
# 17                                               Animal
# 18                                          Bad Company
# 19                                   Love-Hate-Sex-Pain
# 20                                         Mountain Man
# 21                                    Kick In The Teeth
# 22                                           The Animal
# 23                                           In One Ear
# 24                                        World So Cold
# 25                                       My Best Theory
# 26                                        The Good Life
# 27                                       Scream With Me
# 28                                            Nightmare
# 29                                       Rock That Body
# 30                                          This Is War
# 31                                  Letter From A Thief
# 32                                      Heaven nor Hell
# 33                                          Lisztomania
# 34                                               Fallen
# 35                                              Monster
# 36                               Let Me Hear You Scream
# 37                                  Undisclosed Desires
# 38                                    Between the Lines
# 39                                       Feel Like I Do
# 40                                          Sick Of You
# 41                                       Lesson Learned
# 42                                       This Afternoon
# 43                                      Little Lion Man
# 44                                            End Of Me
# 45                             The Crow & the Butterfly
# 46                                           Impossible
# 47                        Set the Fire to the Third Bar
# 48                                        Your Betrayal
# 49                                                Again
# 50                                       All or Nothing
# 51                                         The Royal We
# 52                                       Broken Strings
# 53                                       Hell Of A Time
# 54                                                Maybe
# 55                                      She's So Lovely
# 56                                                Crash
# 57                                     This Is the Life
# 58                                              Odd One
# 59                                      I Kissed a Girl
# 60                                         Shoot It Out
# 61                                         Just Breathe
# 62                         Don't Look Back into the Sun
# 63                    Give Me A Sign (Forever And Ever)
# 64                                               A-Punk
# 65                                            Crossfire
# 66                                            Heartbeat
# 67                                            Spaceship
# 68                                               Stoned
# 69                                   Can't Stand Me Now
# 70                                            Walk Away
# 71                                   Waking Up in Vegas
# 72                   The Sound (John M. Perkins' Blues)
# 187                                          People Say
# 188                              Digital (Did You Tell)
# 189                                                Pyro
# 190                                   Killing Me Inside
# 191                             You've Seen The Butcher
# 192                                             Justice
# 193                                             Old Man
# 194                                                Dead
# 195                                   Bulletproof Heart
# 196                                          Iridescent
# 197                                This Is Why We Fight
# 198                                    What Ya Gonna Do
# 199                           Junk Of The Heart (Happy)
# 200                        Somebody That I Used To Know
# 201                                             Madness
# 202                                       Chalk Outline
# 203                                               Bully
# 204                                  Been Away Too Long
# 205                                        Live To Rise
# 206                                 Gold On The Ceiling
# 207                                           Too Close
# 208                                               Unity
# 209                                         Some Nights
# 210                                              Ho Hey
# 211                                        Little Talks
# 212                                         Coming Down
# 213                                        We Are Young
# 214                                      Still Counting
# 215                                        You're A Lie
# 216                                         Tongue Tied
# 217                                         I Will Wait
# 218                                           Criticize
# 219                                        BURN IT DOWN
# 220                                   I Miss The Misery
# 221                                 Remember Everything
# 222                                             Enemies
# 223                                          These Days
# 224                                       Absolute Zero
# 225                                       No Resolution
# 226                                Hats Off To The Bull
# 227                                    A Warrior's Call
# 228                                Love Bites (So Do I)
# 229                                          Days Go By
# 230                                        The Collapse
# 231                                      Still Swingin'
# 232                                             Oh Love
# 233                                   Bullet In My Hand
# 234                            Lost In Forever (Scream)
# 235                                      Not Your Fault
# 236                                           It's Time
# 237                                 Standing In The Sun
# 238                                   Monarchy Of Roses
# 239                                         Take A Walk
# 240                                       Midnight City
# 241                     Don't Stop (Color On The Walls)
# 242                                      Eyes Wide Open
# 243                                           Hurricane
# 244                                        Here And Now
# 245                                           I Like It
# 246                                     We Come Running
# 247                               Narcissistic Cannibal
# 248                                      This Means War
# 249                                    Kill Your Heroes
# 250                                     Everybody Talks
# 251                                     The Waiting One
# 252                                            Aberdeen
# 253                                           Satellite
# 254                                    Lost In The Echo
# 255                                      After Midnight
# 256                         Bloody Mary (Nerve Endings)
# 257                                            Runaways
# 258                                         Look Around
# 259                                  Rocky Mountain Way
# 260                                               Blood
# 261                                      Boss' Daughter
# 262                                            Anna Sun
# 263                                         In My Blood
# 264                             Itchin' On A Photograph
# 265                                         Wait For Me
# 266                                         Simple Song
# 267                                                 Now
# 268                                        Shake It Out
# 269                                                  45
# 270                                     Let Yourself Go
# 271                                    Sixteen Saltines
# 272                                     Spread Too Thin
# 273                             Bringing Down The Giant
# 274                                   Love Interruption
# 275                                              Tattoo
# 276                                      Bridge Burning
# 277                                    Curl Of The Burl
# 278                                 Youth Without Youth
# 279                                       Charlie Brown
# 280                                           Satisfied
# 281                                   Jump Into The Fog
# 282                                          Let's Ride
# 283                                      Baby Come Home
# 284                                          Headlights
# 285                                  No Light, No Light
# 286                                     Legendary Child
# 287                                       Figure It Out
# 288                                   Blood For Poppies
# 289                                       Get Thru This
# 290                                 Punching In A Dream
# 291                                              Purple
# 292                                            Backlash
# 293                                            Comeback
# 294                              Race You To The Bottom
# 295                                         Sleep Alone
# 296                                           Afterlife
# 297                                         Settle Down
# 298                                            Soldiers
# 299                                             America
# 300                                         Radioactive
# 301                                     Sweater Weather
# 653                                      Through It All
# 654                                        Genghis Khan
# 655                       You Don't Get Me High Anymore
# 656                                         Still Alive
# 657                                        Fallen Angel
# 658                                         Woman Woman
# 659                                              Mayhem
# 660                                       Falling Apart
# 661                                           Kiss This
# 662                                            Paranoia
# 663                                       Phantom Bride
# 664                                   Prayers/Triangles
# 665                                               Roots
# 666                                             No Good
# 667                             Something To Believe In
# 668                                     Take It From Me
# 669                           Until The World Goes Cold
# 670                                I Don't Care Anymore
# 671                                                 Wow
# 672                                         Switchblade
# 673                                    Sure And Certain
# 674                                 Let Me Live My Life
# 675                                         Black Honey
# 676                                           Here I Am
# 677                                          Soundcheck
# 678                                 Thank God For Girls
# 679                                           In Chains
# 680                                             2:00 AM
# 681                              Prayers For The Damned
# 682                                             Naivety
# 683                                               11:11
# 684                                             Magnets
# 685                                  Stick To Your Guns
# 686                                      Bad Reputation
# 687                                         Life Itself
# 688                                                Move
# 689   In The Age Of The Consecrated Vampire We All G...
# 690                                              Ditmas
# 691                                           High Dive
# 692                                    Show Me A Leader
# 693                                The Eagle Has Landed
# 694                                   That's All I Need
# 695                                              Brazil
# 696                       Circadian Rhythm (Last Dance)
# 697                                                Gone
# 698                                       Sleeping Dogs
# 699                                   King Of The World
# 700                                       Feel It Still
# 701                                            Believer
# 702                                             Thunder
# 703                            Something Just Like This
# 704                                            Heathens
# 705                                     Wish I Knew You
# 706                                               Heavy
# 707                                   Feels Like Summer
# 708                                               Human
# 709                                             The Man
# 710                                                High
# 711                                   Whatever It Takes
# 712                                              Broken
# 713                                     Suit And Jacket
# 714                                                Down
# 715                                              Angela
# 716                                                 Run
# 717                                         Green Light
# 718                                                Ride
# 719                                       Walk On Water
# 720                                    The Night We Met
# 721                           The Sky Is A Neighborhood
# 722                                    Love Is Mystical
# 723                                            No Roots
# 724                                      Sit Next To Me
# 725                                               Blame
# 726                                          Hard Times
# 727                                     Sucker For Pain
# 728                                          Lights Out
# 729                                                Numb
# 730                                      Everything Now
# 731                                            Dig Down
# 732                                      Heavydirtysoul
# 733                                       Rx (Medicate)
# 734                                    Take It All Back
# 735                                            Unsteady
# 736                                     Still Breathing
# 737                                      Cold Cold Cold
# 738                                        The Violence
# 739                                            HandClap
# 740                          I Only Lie When I Love You
# 741                              The Way You Used To Do
# 742                                      Way Down We Go
# 743                                        Up All Night
# 744                                          In The End
# 745                                      One More Light
# 746                                            Reverend
# 747                                      Middle Fingers
# 748                                           Cleopatra
# 749                                          Little One
# 750                                    Lay It All On Me
# 751                                       Lust For Life
# 752                                Don’t Take The Money
# 753                                            Vacation
# 754                                                Help
# 755                                      Waste A Moment
# 756                                    Old Church Choir
# 757                                            One Foot
# 758                                         Fire Escape
# 759                                            Champion
# 760                                    Whole Wide World
# 761                                            Sober Up
# 762                                     Ahead Of Myself
# 763                                       In Cold Blood
# 764                                Don't Take The Money
# 765                                        Highway Tune
# 766                                           One Of Us
# 767                                       Somebody Else
# 768                                             Song #3
# 769                                        Let You Down
# 770                                  Live In The Moment
# 771                                        Lay It On Me
# 772                                             On Hold
# 773                                                Love
# 774                                    My Name Is Human
# 775                                             Darling
# 776                                 Love On The Weekend
# 777                                Hymn For The Weekend
# 778                                      Nimble Bastard
# 779                                          So Tied Up
# 780                                             Ophelia
# 781                                            Go Robot
# 782                                       Chain Breaker
# 783                                            Big Boys
# 784                                      One Night Only
# 785                                    Revolution Radio
# 786                                      Perfect Places
# 787                                      Sweet Disaster
# 788                                      What I've Done
# 789                                           Less Than
# 790                                             Passion
# 791                                        Hot Thoughts
# 792                                All The Pretty Girls
# 793                                        In The Blood
# 794                                            Crawling
# 795                                       Run For Cover
# 796                                               Alone
# 797                                         Wild Horses
# 798                                         Best Friend
# 799                                      World Gone Mad
# 800                                              Broken
# 801                                             Happier
# 802                                             Thunder
# 803                                             Natural
# 804                                          High Hopes
# 805                                      Sit Next To Me
# 806                                   Whatever It Takes
# 807                                       Feel It Still
# 808                           Say Amen (Saturday Night)
# 809                                              Africa
# 810                                            Jumpsuit
# 811                                              Zombie
# ...
# 925                                      Highly Suspect
# 926                                               Queen
# 927                                           Absofacto
# 928                                       Local Natives
# 929   Machine Gun Kelly featuring YUNGBLUD & Travis ...
# 930                                     Young The Giant
# 931                      Illenium featuring Jon Bellion
# 932                           Catfish and The Bottlemen
# 933                                         Oliver Tree
# 934                                           Green Day
# 935                                   twenty one pilots
# 936         YUNGBLUD and Halsey featuring Travis Barker
# 937                                      Mumford & Sons
# 938                       Marshmello featuring Bastille
# 939                                            Godsmack
# 940                                            Slipknot
# 941                                            Bastille
# 942                                         George Ezra
# 943        Ed Sheeran With Chris Stapleton & Bruno Mars
# 944                                   The Glorious Sons
# 945                                             Volbeat
# 946                                           Shinedown
# 947                                          Bad Wolves
# 948                                      Barns Courtney
# 949                                       The Lumineers
# 950                                                Muse
# 951                                    Mumford and Sons
# 952                                               Queen
# 953                                              Weezer
# 954                                            The 1975
# 955                                           I Prevail
# 956                                           Disturbed
# 957                                     Vampire Weekend
# 958                             Five Finger Death Punch
# 959                                        White Reaper
# 960                                               Queen
# 961                                           I Prevail
# 962                                               Queen
# 963                                         Tame Impala
# 964                                 Theory of a Deadman
# 965                      morgxn featuring Walk The Moon
# 966                                               Queen
# 967                                                Korn
# 968                                   Breaking Benjamin
# 969                                               Queen
# 970                                  Judah and The Lion
# 971                  Fall Out Boy featuring Wyclef Jean
# 972                                             Volbeat
# 973                                      The Raconteurs
# 974                                       Cold War Kids
# 975                                           Blink-182
# 976                                       Ozzy Osbourne
# 977                                          half•alive
# 978                                 Of Monsters and Men
# 979                                 Death Cab For Cutie
# 980                                      Dermot Kennedy
# 981                                           Meg Myers
# 982                                               Queen
# 983                                   Foster The People
# 984                                           Disturbed
# 985                                          flora cash
# 986                                           Shinedown
# 987                                         Saint Motel
# 988                                               Shaed
# 989       Smith and Thell featuring Swedish Jam Factory
# 990                                                Beck
# 991                                              Hozier
# 992                                         Dirty Honey
# 993                                        The National
# 994                                 Queen & David Bowie
# 995                                          Papa Roach
# 996                                    Mumford and Sons
# 997                                               Foals
# 998                                           Badflower
# 999                                          flora cash
